# %% [markdown]
# # Object Oriented Programing - Part 1
# ## Or why a data scientist should care about classes

# %% [markdown]
# ## Scenario
#
# You want to build an automated datascience pipeline to monitor and predict stock performance.
# What would you do?
#
# ![stocks](img/stocks.jpeg)

# %% [markdown]
# While we won't complete this today, in order to build that you'd need to:
#
# - describe the limits of custom functions
# - discover where classes are used in python packages
# - identify and paraphrase the vocabulary of Object Oriented Programming
# - build a new small sample class
# - map out the blueprint of a class for the stock monitoring data science pipeline

# %% [markdown]
# ### Let's start with the familiar: functions, why do we care about them?

# %% [markdown]
# But, how is a function like a pipe?

# %% [markdown]
# ![pipes](img/funtions-pipe.jpeg)

# %% [markdown]
# **What if** there was a way to bundle your input data, output data, and a bunch of functions _all together_ in a repeatable fashion?

# %% [markdown]
# Well, _**there is**_.

# %% [markdown]
# Or to put it differently:

# %% [markdown]
# #### HI BILLY MAYS HERE

# %% [markdown]
# ![mayes](img/mayes.png)

# %% [markdown]
# #### Example 1
# When we use `type()` what are we checking?
#
# ```
# example = ["one", "two", 3]
# type(example)
# type(example[-1])
# ```

# %% [markdown]
# `example` is an _object_ of _class type_ **list**

# %% [markdown]
# What can we know about `example` now that we know it is a **list** ?

# %% [markdown]
# #### Example 2
#
# ```
# import pandas as pd
#
# sampledf = pd.Dataframe()
#
# ```

# %%
import pandas as pd

sampledf = pd.DataFrame()

# %% [markdown]
# When we create an "object", using the blue-print of a _class_, even when it is **empty** that is called _initializing_ the object.

# %% [markdown]
# Even though it is empty, it is still an _object_ of _class_ pandas DataFrame.

# %%
type(sampledf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# What do we know we can ask about this object?
# What are its _attributes_ ?

# %%
sampledf.columns
# Out:
# Index([], dtype='object')

# %% [markdown]
# What about _methods_ ? What methods are available for data frames?

# %%
sampledf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame

# %%
sampledf.style
# Out:
# <style  type="text/css" >
# </style><table id="T_c207bc5c_f73a_11e9_ab76_34363b8912ba" ><thead></thead><tbody>
#         </tbody></table>

# %%
sampledf.ftypes
# Out:
# Series([], dtype: object)

# %%
sampledf.iat

# %%
sampledf.ndim
# Out:
# 2

# %% [markdown]
# What other attributes and methods can you use on a dataframe? Try them on `sampledf`<br>
# The methods and attributes for dataframes are found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %% [markdown]
# **Task**: Try working with the methods and attributes of data frames on the `airports.csv` dataset

# %%
airports = pd.read_csv('airports.csv')

# %%
airports.columns
# Out:
# Index(['IATA_CODE', 'AIRPORT', 'CITY', 'STATE', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE'],
#       dtype='object')

# %%
airports.shape
# Out:
# (322, 7)

# %%
airports.dtypes
# Out:
# IATA_CODE     object
# AIRPORT       object
# CITY          object
# STATE         object
# COUNTRY       object
# LATITUDE     float64
# LONGITUDE    float64
# dtype: object

# %%
airports.ftypes
# Out:
# IATA_CODE     object:dense
# AIRPORT       object:dense
# CITY          object:dense
# STATE         object:dense
# COUNTRY       object:dense
# LATITUDE     float64:dense
# LONGITUDE    float64:dense
# dtype: object

# %%
airports.ndim
# Out:
# 2

# %%
airports.iat

# %%
airports.style
# Out:
# <style  type="text/css" >
# </style><table id="T_2a1bddb4_f73b_11e9_ab76_34363b8912ba" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >IATA_CODE</th>        <th class="col_heading level0 col1" >AIRPORT</th>        <th class="col_heading level0 col2" >CITY</th>        <th class="col_heading level0 col3" >STATE</th>        <th class="col_heading level0 col4" >COUNTRY</th>        <th class="col_heading level0 col5" >LATITUDE</th>        <th class="col_heading level0 col6" >LONGITUDE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col0" class="data row0 col0" >ABE</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col1" class="data row0 col1" >Lehigh Valley International Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col2" class="data row0 col2" >Allentown</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col3" class="data row0 col3" >PA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col4" class="data row0 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col5" class="data row0 col5" >40.6524</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow0_col6" class="data row0 col6" >-75.4404</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col0" class="data row1 col0" >ABI</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col1" class="data row1 col1" >Abilene Regional Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col2" class="data row1 col2" >Abilene</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col3" class="data row1 col3" >TX</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col4" class="data row1 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col5" class="data row1 col5" >32.4113</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow1_col6" class="data row1 col6" >-99.6819</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col0" class="data row2 col0" >ABQ</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col1" class="data row2 col1" >Albuquerque International Sunport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col2" class="data row2 col2" >Albuquerque</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col3" class="data row2 col3" >NM</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col4" class="data row2 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col5" class="data row2 col5" >35.0402</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow2_col6" class="data row2 col6" >-106.609</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col0" class="data row3 col0" >ABR</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col1" class="data row3 col1" >Aberdeen Regional Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col2" class="data row3 col2" >Aberdeen</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col3" class="data row3 col3" >SD</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col4" class="data row3 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col5" class="data row3 col5" >45.4491</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow3_col6" class="data row3 col6" >-98.4218</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col0" class="data row4 col0" >ABY</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col1" class="data row4 col1" >Southwest Georgia Regional Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col2" class="data row4 col2" >Albany</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col3" class="data row4 col3" >GA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col4" class="data row4 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col5" class="data row4 col5" >31.5355</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow4_col6" class="data row4 col6" >-84.1945</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col0" class="data row5 col0" >ACK</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col1" class="data row5 col1" >Nantucket Memorial Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col2" class="data row5 col2" >Nantucket</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col3" class="data row5 col3" >MA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col4" class="data row5 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col5" class="data row5 col5" >41.2531</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow5_col6" class="data row5 col6" >-70.0602</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col0" class="data row6 col0" >ACT</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col1" class="data row6 col1" >Waco Regional Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col2" class="data row6 col2" >Waco</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col3" class="data row6 col3" >TX</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col4" class="data row6 col4" >USA</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col5" class="data row6 col5" >31.6113</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow6_col6" class="data row6 col6" >-97.2305</td>
#             </tr>
#             <tr>
#                         <th id="T_2a1bddb4_f73b_11e9_ab76_34363b8912balevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow7_col0" class="data row7 col0" >ACV</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow7_col1" class="data row7 col1" >Arcata Airport</td>
#                         <td id="T_2a1bddb4_f73b_11e9_ab76_34363b8912barow7_col2" class="data ro

# %% [markdown]
# ### Quick knowledge check:

# %% [markdown]
# - Where can you find the list of available attributes and methods for a pre-created class?

# %% [markdown]
# - what's the key difference between an attribute and a method?

# %% [markdown]
# - What is the appropriate sequence of these words?  A variable becomes an _______ when you _______ a _______ .
#  - A: Initialize
#  - B: Class
#  - C: Object

# %% [markdown]
# ### So creating a _class_ is essentially creating a _blueprint_ for how you want to store and manipulate data.
#
# ![blueprint](img/blueprint.jpeg)

# %% [markdown]
# ## Quick Scavenger Hunt!!
# - In small groups - use the code links bellow to find where each object is created as a *class*.
# - Then find the location in the code where a method or attribute you have used is _defined_.
# - Share the links to the exact lines of code on the class slack channel!

# %% [markdown]
# Matplotlib:
# - [matplotlib axes](https://matplotlib.org/3.1.1/_modules/matplotlib/axes/_axes.html)
# - [matplotlib figure](https://matplotlib.org/3.1.1/_modules/matplotlib/figure.html)
#
# Seaborn:
# - [Facet grid](https://github.com/mwaskom/seaborn/blob/master/seaborn/axisgrid.py)
#
# Pandas:
# - [series](https://github.com/pandas-dev/pandas/blob/master/pandas/core/series.py)

# %% [markdown]
# ### Let's start by making a car `class` and giving it some `attributes`

# %%
class Car():
    pass

# %%
ferrari = Car()
lambo = Car()

# %% [markdown]
# #### Check the class of lambo

# %%
type(lambo)
# Out:
# __main__.Car

# %% [markdown]
# #### Can assign attributes to a class object after it's been defined and intitialized

# %%
ferrari.max_speed = 200
ferrari.max_speed
# Out:
# 200

# %% [markdown]
# #### But what if we try to return the `max_speed` of lambo?

# %%
lambo.max_speed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-23a8731a26d4> in <module>
# ----> 1 lambo.max_speed
#
# AttributeError: 'Car' object has no attribute 'max_speed'

# %% [markdown]
# #### Let's update our car class so it has more attributes

# %%
class Car():
    wheels = 4

# %%
ford = Car()
ford.wheels
# Out:
# 4

# %% [markdown]
# #### What if we wanted to set some parameters when we initialize the object?

# %%
class Car():
    wheels = 4
    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type

# %%
lambo = Car(200, 'sport')

# %% [markdown]
# #### Confirm our assignment worked

# %%
print(lambo.wheels)
print(lambo.max_speed)
print(lambo.c_type)
# Out:
# 4
# 200
# sport

# %% [markdown]
# #### What if you try to initialize it without one of the terms?

# %%
test = Car(55)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-4d3a40aca94d> in <module>
# ----> 1 test = Car(55)
#
# TypeError: __init__() missing 1 required positional argument: 'c_type'

# %% [markdown]
# ## Now let's create a method for our car class

# %%
class Car():
    wheels = 4

    def __init__(self, max_speed, c_type):
        self.max_speed = max_speed
        self.c_type = c_type
        self.moving = False

    def go(self):
        print('going')
        self.moving = True
    
    def stop(self):
        print('stopped')
        self.moving = False

# %%
lambo = Car(200, 'sport')

# %% [markdown]
# #### **Task** create another method for car `stop`
#
# - stop should print 'stopped'
# - stop should set the attribute `moving` to `False`

# %%
lambo.stop()
# Out:
# stopped

# %% [markdown]
# **Task**: Make a pizza class<br>
#
# - Pizza should take one topping and the size of the pizza when instantiated
# - Pizza should have an attribute `toppings` that stores toppings in a list
# - Pizza should have methods `.add_topping`, `print_toppings`, and `remove_topping`

# %%
class Pizza():
    def __init__(self, topping, size):
        self.toppings = [topping]
        self.size = size
    
    def add_topping(self, topping):
        self.toppings.append(topping)
    
    def print_toppings(self):
        print(self.toppings)
    
    def remove_topping(self, topping):
        self.toppings.remove(topping)

# %%
hawaiian = Pizza("pineapple", "12in", "prepared")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-dbcd1354e545> in <module>
# ----> 1 hawaiian = Pizza("pineapple", "12in", "prepared")
#
# <ipython-input-66-4dd6f631b388> in __init__(self, topping, size, order_status)
#       3         self.toppings = [topping]
#       4         self.size = size
# ----> 5         self.order_status = none
#       6
#       7     def add_topping(self, topping):
#
# NameError: name 'none' is not defined

# %%
hawaiian.print_toppings()
# Out:
# ['pineapple']

# %%
hawaiian.add_topping('ham')
hawaiian.print_toppings()
# Out:
# ['pineapple', 'ham']

# %% [markdown]
# **Extra Credit**
#
# - Pizza should have an attribute "order_status" that starts as equaling `none`. order_status should change depending on the methods:
#  - `done_adjusting_order`
#  - `preparing`
#  - `delivering`
#  - `delivered`
# - order_status, when called, should return in the form of a sentence.

# %%
class Pizza():
    def __init__(self, topping, size, order_status):
        self.toppings = [topping]
        self.size = size
        self.order_status = none
    
    def add_topping(self, topping):
        self.toppings.append(topping)
    
    def print_toppings(self):
        print(self.toppings)
    
    def remove_topping(self, topping):
        self.toppings.remove(topping)
        
    def done_adjusting_order(self):
        self.order_status = "I am done adjusting my order."
    
    def preparing(self):
        self.order_status = "Order is being prepared."
        
    def delivering(self):
        self.order_status = "Order is out for delivery."
        
    def delivered(self):
        self.order_status = "Order has been delivered."

# %%
hawaiian.order_status()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-9311f5e520db> in <module>
# ----> 1 hawaiian.order_status()
#
# AttributeError: 'Pizza' object has no attribute 'order_status'

# %% [markdown]
# ### Integration
# Make a plan for a stock class
#
# - What would you want it to take when instantiated?
# - what methods would you want it to have?
# - for predicting, would you want it to default to one modeling technique? or would you be able to specify?
# - What input data would it take?
# - What attributes would you want to be able to reference?

# %% [markdown]
# ## Reflection
#
# ![traffic](img/stoplight.jpeg)
#
# [Exit Ticket](https://docs.google.com/forms/d/1r-AHQ8HdCuWpepbu4CKlKULeofEiTGfR7rKgKO-oyRI/edit)
